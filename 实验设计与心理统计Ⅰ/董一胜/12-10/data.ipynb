# %%
import pandas as pd 
import seaborn as sns
df = pd.read_excel('data.xlsx')
df.describe()
# Out:
#                分数   组距        分组  Unnamed: 3  Unnamed: 4
# count  100.000000  1.0   14.0000   15.000000  100.000000
# mean    79.680000  3.0   82.0000    6.666667   78.840000
# std      7.026472  NaN   12.5499    6.332080    7.148808
# min     62.000000  3.0   62.5000    0.000000   60.000000
# 25%     75.000000  3.0   72.2500    1.500000   75.000000
# 50%     79.750000  3.0   82.0000    4.000000   78.000000
# 75%     84.000000  3.0   91.7500   10.500000   84.000000
# max     98.000000  3.0  101.5000   20.000000   96.000000

# %%
import matplotlib
font_list = matplotlib.font_manager.fontManager.ttflist
for font in font_list:
    if ('Song' in font.name) or ('Hei' in font.name):
        print(font.name)
# Out:
# Microsoft JhengHei
# STSong
# Microsoft YaHei
# Microsoft JhengHei
# Adobe Song Std
# FZQingKeBenYueSongS-R-GB
# Microsoft YaHei
# FZLanTingHeiS-DB-GB
# Heiti TC
# FangSong_GB2312
# SongTi_GB2312
# FangSong
# Microsoft YaHei
# Microsoft JhengHei
# SimHei

# %%
import numpy as np 
bins = np.arange(59.5,df['分数'].max()+3,3)
bins
# Out:
# array([59.5, 62.5, 65.5, 68.5, 71.5, 74.5, 77.5, 80.5, 83.5, 86.5, 89.5,
#        92.5, 95.5, 98.5])

# %%
df['group'] = pd.cut(df['分数'],bins,right=False)
df
# Out:
#       分数   组距    分组  Unnamed: 3  Unnamed: 4         group
# 0   76.0  3.0  62.5         1.0          96  [74.5, 77.5)
# 1   88.0  NaN  65.5         1.0          96  [86.5, 89.5)
# 2   89.0  NaN  68.5         4.0          93  [86.5, 89.5)
# 3   75.0  NaN  71.5         7.0          93  [74.5, 77.5)
# 4   79.5  NaN  74.5        11.0          93  [77.5, 80.5)
# ..   ...  ...   ...         ...         ...           ...
# 95  83.5  NaN   NaN         NaN          66  [83.5, 86.5)
# 96  70.0  NaN   NaN         NaN          66  [68.5, 71.5)
# 97  73.5  NaN   NaN         NaN          66  [71.5, 74.5)
# 98  73.0  NaN   NaN         NaN          63  [71.5, 74.5)
# 99  70.5  NaN   NaN         NaN          60  [68.5, 71.5)
#
# [100 rows x 6 columns]

# %%
q1 = df['分数'].quantile(0.75)
q2 = df['分数'].quantile(0.25)
q3 = df['分数'].quantile(0.50)

print(q1)
print(q2)
print(q3)
# Out:
# 84.0
# 75.0
# 79.75

# %%
df['group'].value_counts()
# Out:
# group
# [77.5, 80.5)    19
# [80.5, 83.5)    17
# [74.5, 77.5)    14
# [83.5, 86.5)    11
# [71.5, 74.5)    10
# [86.5, 89.5)     8
# [68.5, 71.5)     7
# [89.5, 92.5)     4
# [65.5, 68.5)     3
# [92.5, 95.5)     3
# [95.5, 98.5)     2
# [59.5, 62.5)     1
# [62.5, 65.5)     1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig.set_size_inches(w=20,h=12)
str = np.arange(60,105,3)
ax.set(xlim=(57,102), xticks=np.linspace(60,99,14),ylim=(0, 25), yticks=np.linspace(0, 20, 5))

plt.hist(df.iloc[:,4],str,color='white',edgecolor = 'black')
plt.tick_params(labelsize=20,bottom = False)

labels = ax.get_xticklabels()+ ax.get_yticklabels()
[label.set_fontname('Arial') for label in labels]
plt.ylabel('次\n数', font={'family':'SongTi_GB2312','size':20},rotation = 360,labelpad=20,linespacing = 1.6)
ax.tick_params('both', which='major', direction='in')


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(w=14,h=20)
str = np.arange(60,105,3)
ax.set(xlim=(57,102), xticks=np.linspace(60,99,14),ylim=(0,100), yticks=np.linspace(5, 100, 20))





ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tick_params(labelsize=18)
ax.tick_params('both', which='major', direction='in')
# plt.scatter([75],[36],s=25,c=[0.5,0.5,0.5])
# plt.scatter([79.75],[55],s=25,c=[0.5,0.5,0.5])
# plt.scatter([84],[83],s=25,c=[0.5,0.5,0.5])

ax2 = ax.twinx()
ax2.plot()
ax2.spines['top'].set_visible(False)
ax2.set(ylim=(0,100),yticks=np.linspace(5, 100, 20))
ax2.set_yticklabels(np.int8((np.linspace(95,0,20))))

plt.text(75-2.5, 27+1, '(75.4, 75)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
plt.text(79.75-4.5, 50+1, '(79.7, 50)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
plt.text(84-2.5, 77+1, '(84.0, 25)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])

fig2  = plt.plot(x1,y1,'grey',linewidth = 1)

plt.plot([75.4, 75.4], [0, 25], c=[0.8,0.8,0.8], linestyle='--')
plt.plot([75.4,102], [25, 25], c=[0.8,0.8,0.8], linestyle='--')
plt.plot([79.7+0.5, 79.7+0.5], [0, 50], c=[0.8,0.8,0.8], linestyle='--')
plt.plot([79.7+0.5,102], [50, 50], c=[0.8,0.8,0.8], linestyle='--')
plt.plot([84, 84], [0, 75], c=[0.8,0.8,0.8], linestyle='--')
plt.plot([84,102], [75, 75], c=[0.8,0.8,0.8], linestyle='--')
plt.scatter([75.4],[25],s=24,c=[0.5,0.5,0.5])
plt.scatter([79.7+0.5],[50],s=25,c=[0.5,0.5,0.5])
plt.scatter([84],[75],s=25,c=[0.5,0.5,0.5])
plt.hist(df.iloc[:,4],str,color='white',edgecolor = 'black',cumulative=1,histtype='step')

labels = ax.get_xticklabels()+ ax.get_yticklabels()+ax2.get_yticklabels()
[label.set_fontname('Arial') for label in labels]
plt.tick_params(labelsize=18)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13080\1335551952.py:36: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter([75.4],[25],s=24,c=[0.5,0.5,0.5])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13080\1335551952.py:37: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter([79.7+0.5],[50],s=25,c=[0.5,0.5,0.5])
# ...

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(w=14,h=20)
# str = np.arange(60,105,3)
# ax.set(xlim=(57,102), xticks=np.linspace(60,99,14),ylim=(0,100), yticks=np.linspace(5, 100, 20))




# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.tick_params(labelsize=18)
# ax.tick_params('both', which='major', direction='in')


# plt.plot([75, 75], [0, 27], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 75], [27, 27], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([79.75, 79.75], [0, 50], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 79.75], [50, 50], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([84, 84], [0, 77], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 84], [77, 77], c=[0.8,0.8,0.8], linestyle='--')

# plt.scatter([75],[27],s=25,c=[0.5,0.5,0.5])
# plt.scatter([79.75],[50],s=25,c=[0.5,0.5,0.5])
# plt.scatter([84],[77],s=25,c=[0.5,0.5,0.5])

# plt.hist(df.iloc[:,4],str,color='white',edgecolor = 'black',cumulative=1,histtype='step')

# # ax2 = ax.twinx()
# # ax2.plot()
# # ax2.spines['top'].set_visible(False)
# # ax2.set(ylim=(0,100),yticks=np.linspace(5, 100, 20))
# # ax2.set_yticklabels(np.int8((np.linspace(95,0,20))))

# plt.text(75-2, 28, '(75,27)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(79.75+2, 51, '(79.75,50)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(84-2, 78, '(84,77)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])

# labels = ax.get_xticklabels()+ ax.get_yticklabels()#+ax2.get_yticklabels()
# [label.set_fontname('Arial') for label in labels]
# plt.tick_params(labelsize=18)

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(w=14,h=20)
# str = np.arange(60,105,3)
# ax.set(xlim=(57,102), xticks=np.linspace(60,99,14),ylim=(0,100), yticks=np.linspace(5, 100, 20))




# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.tick_params(labelsize=18)
# ax.tick_params('both', which='major', direction='in')


# plt.plot([75, 75], [0, 27], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 75], [27, 27], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([79.75, 79.75], [0, 55], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 79.75], [55, 55], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([84, 84], [0, 77], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 84], [77, 77], c=[0.8,0.8,0.8], linestyle='--')

# plt.scatter([75],[27],s=25,c=[0.5,0.5,0.5])
# plt.scatter([79.75],[55],s=25,c=[0.5,0.5,0.5])
# plt.scatter([84],[77],s=25,c=[0.5,0.5,0.5])

# plt.hist(df.iloc[:,4],str,color='white',edgecolor = 'black',cumulative=1,histtype='step')


# # ax2 = ax.twinx()
# # ax2.plot()
# # ax2.spines['top'].set_visible(False)
# # ax2.set(ylim=(0,100),yticks=np.linspace(5, 100, 20))
# # ax2.set_yticklabels(np.int8((np.linspace(95,0,20))))

# plt.text(75-2, 28, '(75,27)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(79.75+2, 51, '(79.75,55)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(84-2, 78, '(84,77)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])

# labels = ax.get_xticklabels()+ ax.get_yticklabels()#+ax2.get_yticklabels()
# [label.set_fontname('Arial') for label in labels]
# plt.tick_params(labelsize=18)

# %%
# list=df['分数'].tolist()
# list.sort()
# list

# %%
# df['rankmin'] = df['分数'].rank(ascending=1,method='min')
# plt.scatter(x=df['分数'],y=df['rankmin'])

# %%
# df['rankmax'] = df['分数'].rank(ascending=1,method='max')
# plt.scatter(x=df['分数'],y=df['rankmax'])

# %%
# df['rankave'] = df['分数'].rank(ascending=1,method='average')
# plt.scatter(x=df['分数'],y=df['rankave'])

# %%
# df['rankfirst'] = df['分数'].rank(ascending=1,method='first')
# plt.scatter(x=df['分数'],y=df['rankfirst'])

# %%
# df.to_csv('ranked data.csv',encoding='GB2312')

# %%
# x = df['分数'].tolist()
# x.sort()
# y = df['rankmax'].tolist()
# y.sort()
# plt.plot(x,y)

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(w=14,h=20)

# import numpy as np 
# import matplotlib.pyplot as plt 


# ax.set(xlim=(57,102), xticks=np.linspace(60,99,14),ylim=(0,100), yticks=np.linspace(5, 100, 20))
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.tick_params(labelsize=18)
# ax.tick_params('both', which='major', direction='in')

# plt.plot([75, 75], [0, 27], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 75], [27, 27], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([79.75, 79.75], [0, 50], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 79.75], [50, 50], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([84, 84], [0, 77], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 84], [77, 77], c=[0.8,0.8,0.8], linestyle='--')



# plt.text(75-1.5, 27+1, '(75,27)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(79.75-3, 50+1, '(79.75,50)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(84-1.5, 77+1, '(84,77)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])

# plt.plot(x,y,'black')
# plt.scatter([75],[27],s=25,c=[0.5,0.5,0.5])
# plt.scatter([79.75],[50],s=25,c=[0.5,0.5,0.5])
# plt.scatter([84],[77],s=25,c=[0.5,0.5,0.5])
# labels = ax.get_xticklabels()+ ax.get_yticklabels()
# [label.set_fontname('Arial') for label in labels]
# plt.tick_params(labelsize=18)

# %%
# df3 = pd.read_csv("ranked data.csv",encoding='GB2312')

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(w=14,h=20)

# import numpy as np 
# import matplotlib.pyplot as plt 


# ax.set(xlim=(57,102), xticks=np.linspace(60,99,14),ylim=(0,100), yticks=np.linspace(5, 100, 20))
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.tick_params(labelsize=18)
# ax.tick_params('both', which='major', direction='in')

# plt.plot([75.4, 75.4], [0, 25], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 75.4], [25, 25], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([79.7+0.5, 79.7+0.5], [0, 50], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 79.7+0.5], [50, 50], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([84, 84], [0, 75], c=[0.8,0.8,0.8], linestyle='--')
# plt.plot([0, 84], [75, 75], c=[0.8,0.8,0.8], linestyle='--')


# y1 = df3['sum'].tolist()
# x1 = df3['limitU'].tolist()
# plt.text(75-1.5, 27+1, '(75.4,25)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(79.75-3, 50+1, '(79.7,50)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])
# plt.text(84-1.5, 77+1, '(84.0,75)', ha='center', va='bottom', fontsize=15,color= [0.3,0.3,0.3])

# plt.plot(x1,y1,'black')
# plt.scatter([75.4],[25],s=24,c=[0.5,0.5,0.5])
# plt.scatter([79.7+0.5],[50],s=25,c=[0.5,0.5,0.5])
# plt.scatter([84],[75],s=25,c=[0.5,0.5,0.5])
# labels = ax.get_xticklabels()+ ax.get_yticklabels()
# [label.set_fontname('Arial') for label in labels]
# plt.tick_params(labelsize=18)
