# %%
import pandas as pd

df = pd.read_excel('EPQ.xlsx')
df
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0             1          女           1           1           1           1
# 1             2          男           4           1           0           1
# 2             3          男           1           1           0           1
# 3             4          男           3           0           0           1
# 4             5          男           1           0           1           1
# ..          ...        ...         ...         ...         ...         ...
# 266         267          男           5           0           0           1
# 267         268          男           5           0           0           1
# 268         268          男           5           0           0           1
# 269         269          男           5           1           0           1
# 270         270          男           3           1           0           1
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# count  271.000000  271.000000  271.000000  271.000000  271.000000  271.000000
# mean   135.988930    3.568266    0.612546    0.077491    0.933579    0.826568
# std     78.356237    1.822175    0.488070    0.267863    0.249477    0.379321
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     68.500000    1.000000    0.000000    0.000000    1.000000    1.000000
# 50%    136.000000    4.000000    1.000000    0.000000    1.000000    1.000000
# 75%    203.500000    5.000000    1.000000    0.000000    1.000000    1.000000
# max    270.000000    6.000000    1.000000    1.000000    1.000000    1.000000
#
#        Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  Unnamed: 81  \
# count  271.000000  271.000000  271.000000   271.000000  ...   271.000000
# mean     0.907749    0.959410    0.926199     0.103321  ...     0.630996
# ...

# %%
df.dropna()
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 1             2          男           4           1           0           1
# 2             3          男           1           1           0           1
# 3             4          男           3           0           0           1
# 4             5          男           1           0           1           1
# 5             6          女           3           0           0           1
# ..          ...        ...         ...         ...         ...         ...
# 266         267          男           5           0           0           1
# 267         268          男           5           0           0           1
# 268         268          男           5           0           0           1
# 269         269          男           5           1           0           1
# 270         270          男           3           1           0           1
#
# ...
